# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 1070430             6991963  84.7% Test.csv
#
# 1403853             7686426  81.7% Train.csv
#
# 251796             1800009  86.0% SampleSubmission.csv

# %% [markdown]
# 1031026 6991963 85.2541% Test.csv
#
# 1285648 7686426 83.2738% Train.csv
#
# 55916  1800009  96.8936% SampleSubmission.csv

# %% [markdown]
# 9512138             9511403  -0.0% test.djvu
#
# 320366              325528   1.6% report.pdf

# %% [markdown]
# 9594466 9511403 -0.0% test.djvu
#
# 324174 325528 0.41594% report.pdf

# %%
x = [40, 205, 1758, 6786, 6829, 7507]
y1 = [91, 91, 77, 1515, 1438, 1849]
y2 = [67, 67, 246, 1113, 1046, 1371]

# %%
Y1 = [64, 319, 711, 944]
X = [57, 289, 680, 854]
Y2 = [56, 277, 602, 846]

# %%
dpi = 80
fig = plt.figure(dpi = dpi, figsize = (1024 / dpi, 512 / dpi) )

plt.title("Хорошо сжимаемые данные") # заголовок
plt.xlabel("Размер до сжатия")         # ось абсцисс
plt.ylabel("Размер после сжатия")    # ось ординат
plt.grid()              # включение отображение сетки
plt.plot(x, y1, label = "kp")
plt.plot(x, y2, label = "gzip") 
plt.legend(loc = 'upper left')
fig.savefig('good.png')

# %%
dpi = 80
fig = plt.figure(dpi = dpi, figsize = (1024 / dpi, 512 / dpi) )
plt.title("Плохо сжимаемые данные") # заголовок
plt.xlabel("Размер до сжатия")         # ось абсцисс
plt.ylabel("Размеры после сжатия")    # ось ординат
plt.grid()              # включение отображение сетки
plt.plot(X, Y1, label = "kp")
plt.plot(X, Y2, label = "gzip") 
plt.legend(loc = 'upper left')
fig.savefig('bad.png')
